# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()

# %%
# !pip install pyyaml

# %%
import sys
sys.path.append('/mnt/code/domino-extensions-api/code-examples/')

# %% [markdown]
# ### Import client libraries

# %%
import client.domsed_client as dc

# %% [markdown]
# #### Listing mutations

# %%
dc.list()

# %% [markdown]
# #### Create Mutation

# %%
dc.apply_file('/mnt/code/domino-extended-api/code-examples/mutations/label.yaml')
dc.list()

# %% [markdown]
# #### Get Mutation

# %%
dc.get('label')

# %% [markdown]
# #### Delete Mutation

# %%
dc.delete('label')
