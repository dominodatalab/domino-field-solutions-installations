# %%
# this code is generated by the Domino Code Assist toolbar button
import domino_code_assist as dca
dca.init()

# %%
# !pip install pyyaml

# %%
import sys
sys.path.append('/mnt/code/domino-extended-api/code-examples/')

# %% [markdown]
# ### Import client libraries

# %%
import client.domsed_client as dc

# %% [markdown]
# #### Listing mutations

# %%
dc.list()
# Out:
# Listing Mutations
#
# 	extendedapi
# 	irsa
# 	jit
# 	modify-sec-cont

# %% [markdown]
# #### Create Mutation

# %%
dc.apply_file('/mnt/code/domino-extended-api/code-examples/mutations/label.yaml')
dc.list()
# Out:
# 2023-10-09 17:26:58,066 - domsed_client - WARNING - Publishing Mutation To Domsed
# Applied Mutation
# {"apiVersion":"apps.dominodatalab.com/v1alpha1","kind":"Mutation","metadata":{"creationTimestamp":"2023-10-09T17:26:58Z","generation":1,"managedFields":[{"apiVersion":"apps.dominodatalab.com/v1alpha1","fieldsType":"FieldsV1","fieldsV1":{"f:rules":{}},"manager":"OpenAPI-Generator","operation":"Update","time":"2023-10-09T17:26:58Z"}],"name":"label","namespace":"domino-platform","resourceVersion":"250137192","uid":"914a55d9-e6e4-4f20-8a57-f9ef04a611e1"},"rules":[{"matchBuilds":false,"modifyLabel":{"key":"foo.com/bar"}}]}
#
# Listing Mutations
#
# 	extendedapi
# 	irsa
# 	jit
# 	label
# 	modify-sec-cont

# %% [markdown]
# #### Get Mutation

# %%
dc.get('label')
# Out:
# 2023-10-09 17:24:43,111 - domsed_client - WARNING - Get Mutationlabel
# Printing Mutation: label
#
# {"apiVersion":"apps.dominodatalab.com/v1alpha1","kind":"Mutation","metadata":{"creationTimestamp":"2023-10-09T17:24:36Z","generation":1,"managedFields":[{"apiVersion":"apps.dominodatalab.com/v1alpha1","fieldsType":"FieldsV1","fieldsV1":{"f:rules":{}},"manager":"OpenAPI-Generator","operation":"Update","time":"2023-10-09T17:24:36Z"}],"name":"label","namespace":"domino-platform","resourceVersion":"250136144","uid":"a5719d1e-c733-4217-98ce-1bbb5f6bab4b"},"rules":[{"matchBuilds":false,"modifyLabel":{"key":"foo.com/bar"}}]}

# %% [markdown]
# #### Delete Mutation

# %%
dc.delete('label')
# Out:
# 2023-10-09 17:24:47,516 - domsed_client - WARNING - Deleting Mutationlabel
# 2023-10-09 17:24:47,569 - domsed_client - WARNING - {"apiVersion":"v1","details":{"group":"apps.dominodatalab.com","kind":"mutations","name":"label","uid":"a5719d1e-c733-4217-98ce-1bbb5f6bab4b"},"kind":"Status","metadata":{},"status":"Success"}
# Deleted Mutation label
